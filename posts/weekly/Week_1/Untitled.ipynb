# %% [raw]
# ---
# title: "Week 1"
# date: 2026-04-07
# categories: [weekly]
# draft: true
# ---

# %% [markdown]
# # I Wrote a CUDA Kernel from Scratch and Called It from Python Two Ways
#
# I spent a week building a mini inference engine for Llama — starting from a raw CUDA kernel and ending with benchmarks that show exactly why my code is 20x slower than PyTorch. Here's everything I built and everything I learned.
